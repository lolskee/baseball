# %%
import pandas as pd 
import re

# %%
master = pd.read_csv('../mlb_data/master_v2.csv')

# %%
master.head()
# Out:
#          batter  batter_batting_order batter_team pitcher_team  \
# 0  Trevor Story                   2.0         COL          ARI
# 1   Denard Span                   1.0          SF          MIL
# 2  Bryce Harper                   3.0         WSH          ATL
# 3    Matt Duffy                   6.0          SF          MIL
# 4    Matt Duffy                   6.0          SF          MIL
#
#    batter_dk_salary  batter_dk_points  batter_home  date        pitcher  \
# 0               3.4              32.0            0   404   Zack Greinke
# 1               4.6              27.0            0   404   Wily Peralta
# 2               4.5              23.0            0   404  Julio Teheran
# 3               4.5              23.0            0   404   Wily Peralta
# 4               4.5              23.0            0   404   Wily Peralta
#
#    pitcher_batting_order              ...                \
# 0                    8.0              ...
# 1                    8.0              ...
# ...
